# %%
import matplotlib.pyplot as plt 
from sklearn import linear_model
import seaborn as sns
import pandas as pd
import numpy as np
import os

# %%
data = pd.read_csv("c:/Users/Usuario/data.csv")

# %%
data.head(10)
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.plot.scatter(x="metro", y="precio")
plt.show()

# %%
regresion = linear_model.LinearRegression()

# %%
precios = data["metro"].values.reshape((-1,1))

# %%
modelo = regresion.fit(metros, data["precio"])

# %%
print("Interseccion(b)", modelo.intercept_)
print("Pendiente(m)", modelo.coef_)
# Out:
# Interseccion(b) 361.25714285714287
# Pendiente(m) [5.64571429]

# %%
entrada= [[7.5],[10.0],[12.5],[15.0],[17.5],[20.0]]
predicciones=modelo.predict(entrada)
print(predicciones)
# Out:
# [403.6        417.71428571 431.82857143 445.94285714 460.05714286
#  474.17142857]

# %%
data.plot.scatter(x="metro", y="precio", label='Datos Originales')
plt.scatter(entrada, predicciones, color='red')
plt.plot(entrada, predicciones, color='black', label='Linea de Regresion')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
